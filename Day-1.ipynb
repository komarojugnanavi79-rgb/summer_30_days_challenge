# %%
print("Let's start the challenge,I will stay consistent")
# Out:
# Let's start the challenge,I will stay consistent

# %%
name=input("enter your name:")
print("welcome," ,  name , "!Glad to have you here.")
# Out:
# enter your name:Gnanavi
# welcome, Gnanavi !Glad to have you here.

# %%
9a=int(input("a = "))
b=int(input("b = "))
sum=a+b
print("Sum of two numbers",sum)
# Out:
# a = 56
# b = 8
# Sum of two numbers 64

# %%
a=int(input("a = ")9)
b=int(input("b = "))
print("Remainder",a%b)
# Out:
# a = 56
# b = 8
# Remainder 0

# %%
90a = float(input("a="))
b = float(input("b="))
c = float(input("c="))
average = (a + b + c) / 3
print("The average of three numbers is:",average)
# Out:
# a=67
# b=8
# c=9
# The average of three numbers is: 28.0

# %%
a=input("enter a value for variable a :")
b=input("enter a value for variable b :")

print("Befor Swapping a:",a,",b:",b)

a,b=b,a

print("After Swapping a:",a,",b:",b)
# Out:
# enter a value for variable a :dad
# enter a value for variable b :bad
# Befor Swapping a: dad ,b: bad
# After Swapping a: bad ,b: dad

# %%
99subj1=float(input("Enter marks for subject 1:"))
subj2=float(input("Enter marks for subject 2:"))
subj3=float(input("Enter marks for subject 3:"))
subj4=float(input("Enter marks for subject 4:"))
subj5=float(input("Enter marks for subject 5:"))

total_marks = subj1 + subj2 + subj3 + subj4 + subj5
percentage = (total_marks / 500)*100

print("------*Result*------")
print("Total Marks :", total_marks)
print("Percentage:", percentage)
# Out:
# Enter marks for subject 1:98
# Enter marks for subject 2:7
# Enter marks for subject 3:65
# Enter marks for subject 4:90
# Enter marks for subject 5:94
# ------*Result*------
# Total Marks : 354.0
# Percentage: 70.8

# %%
celsius = float(input("Enter temperature in celsius (°C):"))
fahrenheit = (celsius* (9/5)+32)

print("Converting Cesius into Fahrenhiet:",fahrenheit,"°f")
# Out:
# Enter temperature in celsius (°C):789
# Converting Cesius into Fahrenhiet: 1452.2 °f

# %%
Fahrenhiet = float(input("Enter temperature in celsius (°f):"))
celsius = ((Fahrenhiet-32) * 5/9)

print("Converting Cesius into Fahrenhiet:",celsius,"°c")
# Out:
# Enter temperature in celsius (°f):98
# Converting Cesius into Fahrenhiet: 36.666666666666664 °c

# %%
Length = float(input("Enter length of the cuboid:"))
Breadth = float(input("Enter breadth of the cuboid:"))
Height = float(input("Enter height of the cuboid:"))
Volume=Length*Breadth*Height
print("Volume of the cuboid is :",Volume)
# Out:
# Enter length of the cuboid:68
# Enter breadth of the cuboid:90
# Enter height of the cuboid:09
# Volume of the cuboid is : 55080.0
